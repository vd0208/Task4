# %% [markdown]
# # Tokenization and Lemmatization
#
# This notebook performs tokenization, stopword removal, and lemmatization on cleaned text.

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from nltk.stem import WordNetLemmatizer
import nltk

nltk.data.path.append('/Users/wxs/nltk_data')

# %% [markdown]
# ## Load cleaned data

# %%
df = pd.read_csv('/Users/wxs/Downloads/customer_support_tickets_cleaned.csv')
df['clean_body'] = df['clean_body'].fillna('')
print(f'Loaded {len(df)} rows')
df.head()
# Out:
# Loaded 28261 rows
#                                              subject  \
# 0                                 Account Disruption
# 1  Query About Smart Home System Integration Feat...
# 2                  Inquiry Regarding Invoice Details
# 3  Question About Marketing Agency Software Compa...
# 4                                      Feature Query
#
#                                                 body  \
# 0  Dear Customer Support Team,\n\nI am writing to...
# 1  Dear Customer Support Team,\n\nI hope this mes...
# 2  Dear Customer Support Team,\n\nI hope this mes...
# 3  Dear Support Team,\n\nI hope this message reac...
# 4  Dear Customer Support,\n\nI hope this message ...
#
#                                               answer      type  \
# 0  Thank you for reaching out, <name>. We are awa...  Incident
# 1  Thank you for your inquiry. Our products suppo...   Request
# 2  We appreciate you reaching out with your billi...   Request
# 3  Thank you for your inquiry. Our product suppor...   Problem
# 4  Thank you for your inquiry. Please specify whi...   Request
#
#                    queue priority language  version    tag_1       tag_2  \
# 0      Technical Support     high       en     51.0  Account  Disruption
# 1  Returns and Exchanges   medium       en     51.0  Product     Feature
# 2   Billing and Payments      low       en     51.0  Billing     Payment
# 3    Sales and Pre-Sales   medium       en     51.0  Product     Feature
# 4      Technical Support     high       en     51.0  Feature     Product
#
#            tag_3          tag_4         tag_5 tag_6 tag_7 tag_8  \
# 0         Outage             IT  Tech Support   NaN   NaN   NaN
# 1   Tech Support            NaN           NaN   NaN   NaN   NaN
# 2        Account  Documentation      Feedback   NaN   NaN   NaN
# 3       Feedback   Tech Support           NaN   NaN   NaN   NaN
# 4  Documentation       Feedback           NaN   NaN   NaN   NaN
#
#                                           clean_body  word_count_before  \
# 0  i am writing to report a significant problem w...                 82
# 1  i hope this message reaches you well i am reac...                 76
# 2  i hope this message finds you well i am reachi...                 91
# 3  i hope this message reaches you well i am reac...                 97
# 4  dear customer support i hope this message reac...                 97
#
#    word_count_after
# 0                80
# 1                74
# 2                81
# 3                96
# 4                98

# %% [markdown]
# ## Tokenization

# %%
stop_words = set(ENGLISH_STOP_WORDS)

custom_stopwords = {
    'dear', 'customer', 'support', 'team',
    'hello', 'hi', 'thanks', 'thank',
    'regards', 'please', 'kindly',
    'hope', 'message'
}

def tokenize_text(text):
    if text is None:
        return []

    tokens = text.split()

    tokens = [
        word for word in tokens
        if word not in stop_words
        and word not in custom_stopwords
        and len(word) > 2
    ]

    tokens = list(dict.fromkeys(tokens))

    return tokens

df['tokens'] = df['clean_body'].apply(tokenize_text)
df[['clean_body', 'tokens']].head()
# Out:
#                                           clean_body  \
# 0  i am writing to report a significant problem w...
# 1  i hope this message reaches you well i am reac...
# 2  i hope this message finds you well i am reachi...
# 3  i hope this message reaches you well i am reac...
# 4  dear customer support i hope this message reac...
#
#                                               tokens
# 0  [writing, report, significant, problem, centra...
# 1  [reaches, reaching, request, detailed, informa...
# 2  [finds, reaching, request, clarification, bill...
# 3  [reaches, reaching, ask, compatibility, produc...
# 4  [reaches, good, health, eager, learn, features...

# %% [markdown]
# ## Lemmatization

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_tokens(tokens):
    result = []
    for word in tokens:
        word = lemmatizer.lemmatize(word, 'v')
        word = lemmatizer.lemmatize(word, 'n')
        result.append(word)

    result = list(dict.fromkeys(result))

    return result

df['processed_tokens'] = df['tokens'].apply(lemmatize_tokens)
df['processed_text'] = df['processed_tokens'].apply(lambda x: ' '.join(x))

df = df[df['processed_text'].str.strip() != ''].reset_index(drop=True)

df[['tokens', 'processed_tokens', 'processed_text']].head()
# Out:
#                                               tokens  \
# 0  [writing, report, significant, problem, centra...
# 1  [reaches, reaching, request, detailed, informa...
# 2  [finds, reaching, request, clarification, bill...
# 3  [reaches, reaching, ask, compatibility, produc...
# 4  [reaches, good, health, eager, learn, features...
#
#                                     processed_tokens  \
# 0  [write, report, significant, problem, centrali...
# 1  [reach, request, detail, information, capabili...
# 2  [find, reach, request, clarification, bill, pa...
# 3  [reach, ask, compatibility, product, specific,...
# 4  [reach, good, health, eager, learn, feature, p...
#
#                                       processed_text
# 0  write report significant problem centralize ac...
# 1  reach request detail information capability sm...
# 2  find reach request clarification bill payment ...
# 3  reach ask compatibility product specific need ...
# 4  reach good health eager learn feature product ...

# %% [markdown]
# ## Save results

# %%
df.to_csv('processed_tickets_final.csv', index=False)
print(f'Saved {len(df)} rows → processed_tickets_final.csv')
# Out:
# Saved 28256 rows → processed_tickets_final.csv
